# %% [markdown]
# '''
# Autor: Aclelino Damião <p>
# Github:github.com/Aclelino<p>
# E-mail: aclelino@gmail.com<p>
# Instagram: instagram.com/acle.damiao <p>
#
# Linguagem: Python
#
#
# '''

# %%
from PyQt5 import uic,QtWidgets

def botao1():
    
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + "1")
def botao2():
    
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + "2")
    
def botao3():
    
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + "3")
    
def botao4():
    
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + "4")
    
def botao5():
    
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + "5")
    
def botao6():
    
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + "6")


def botao7():
    
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + "7")
    

def botao8():
    
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + "8")
    
def botao9():
    
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + "9")
    
def botao0():

    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + "0")
    
def botao_soma():
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + " + ")
def botao_menos():
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + " - ")
    
def botao_dividir():
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + " / ")
    
def botao_multiplicar():
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + " * ")
    
    
def botao_ponto():
    texto = ui.lineEdit.text()
    lineEdit = ui.lineEdit.setText(texto + ".")
def botao_clear():
    
    lineEdit = ui.lineEdit.setText(" ")
def botao_igual():
    tela = eval(ui.lineEdit.text())
    ui.lineEdit.setText(str(tela))
   

app = QtWidgets.QApplication([])
ui = uic.loadUi("calc.ui")

ui.button_0.clicked.connect(botao0)    
ui.button_1.clicked.connect(botao1)
ui.button_2.clicked.connect(botao2)
ui.button_3.clicked.connect(botao3)
ui.button_4.clicked.connect(botao4)
ui.button_5.clicked.connect(botao5)
ui.button_6.clicked.connect(botao6)
ui.button_7.clicked.connect(botao7)
ui.button_8.clicked.connect(botao8)
ui.button_9.clicked.connect(botao9)
ui.button_p.clicked.connect(botao_ponto)
ui.button_mais.clicked.connect(botao_soma)
ui.button_clear.clicked.connect(botao_clear)
ui.button_igual.clicked.connect(botao_igual)
ui.button_dividi.clicked.connect(botao_dividir)
ui.button_menos.clicked.connect(botao_menos)
ui.button_x.clicked.connect(botao_multiplicar)
ui.show()
app.exec_()
